# %%
import seaborn as sns
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('all_faults_filtered.csv')

# %% [markdown]
# # Segmentar la señal de vibración en pequeñas porciones usando una ventana

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

win_len=1000
stride=200

X=[]
Y=[]


for k in df['fault'].unique():
    
    df_temp_2 = df[df['fault']==k]
    
    for i in np.arange(0,len(df_temp_2)-(win_len),stride):
        temp = df_temp_2.iloc[i:i+win_len,:-1].values
        temp = temp.reshape((1,-1))
        X.append(temp)
        Y.append(df_temp_2.iloc[i+win_len,-1])
    
X=np.array(X)
X=X.reshape((X.shape[0],win_len))



Y=np.array(Y)
encoder= LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
OHE_Y = to_categorical(encoded_Y)

# %%
X.shape
# Out:
# (13848, 1000)

# %% [markdown]
# # Dividir los datos en entrenar y probar

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,OHE_Y,test_size=0.25,shuffle=True)

# %% [markdown]
# # Visualizar los datos usando t-sne antes de usar codificadores automáticos

# %%
X_pre_aen = X

from sklearn.manifold import TSNE

X_t_sne = TSNE(n_components=2, learning_rate='auto',verbose=1, perplexity=40, n_iter=300).fit_transform(X_pre_aen)

tSNEdf = pd.DataFrame(data = X_t_sne, columns = ['t-SNE component 1', 't-SNE component 2'])

tSNEdf['Fault']=Y


# Plot the PC-1 and PC-2
fig, ax = plt.subplots(figsize=(7,7))
sns.scatterplot(x=tSNEdf['t-SNE component 1'],y=tSNEdf['t-SNE component 2'],hue='Fault',
    data=tSNEdf,
    legend="full",
    alpha=0.3)
plt.show()
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 13848 samples in 0.031s...
# [t-SNE] Computed neighbors for 13848 samples in 8.758s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 13848
# [t-SNE] Computed conditional probabilities for sample 2000 / 13848
# [t-SNE] Computed conditional probabilities for sample 3000 / 13848
# [t-SNE] Computed conditional probabilities for sample 4000 / 13848
# [t-SNE] Computed conditional probabilities for sample 5000 / 13848
# [t-SNE] Computed conditional probabilities for sample 6000 / 13848
# [t-SNE] Computed conditional probabilities for sample 7000 / 13848
# [t-SNE] Computed conditional probabilities for sample 8000 / 13848
# [t-SNE] Computed conditional probabilities for sample 9000 / 13848
# [t-SNE] Computed conditional probabilities for sample 10000 / 13848
# [t-SNE] Computed conditional probabilities for sample 11000 / 13848
# [t-SNE] Computed conditional probabilities for sample 12000 / 13848
# [t-SNE] Computed conditional probabilities for sample 13000 / 13848
# [t-SNE] Computed conditional probabilities for sample 13848 / 13848
# [t-SNE] Mean sigma: 0.638989
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.679512
# [t-SNE] KL divergence after 300 iterations: 3.979525

# %%
tSNEdf
# Out:
#        t-SNE component 1  t-SNE component 2 Fault
# 0               1.677142          -0.186991   7IR
# 1               2.636844           0.660284   7IR
# 2               1.862015           0.089320   7IR
# 3               2.715260           1.167849   7IR
# 4               2.953722           0.716867   7IR
# ...                  ...                ...   ...
# 13843          -6.525592          -0.172318     N
# 13844          -5.202087           0.588852     N
# 13845          -6.667678           0.086549     N
# 13846          -5.312728           0.329620     N
# 13847          -6.743831           0.107160     N
#
# [13848 rows x 3 columns]

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Input,Dense, Dropout, Flatten


# from tensorflow.keras.models import load_model
# AE_model = load_model(r'Trained Model\AE_model_gear.h5')


no_classes=len(encoder.classes_)
# build a model
model = Sequential()
model.add(Dense(1024, input_shape=(X.shape[1],), activation='relu')) # input shape is (features,)
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(no_classes, activation='softmax'))
model.summary()

# compile the model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', # this is different instead of binary_crossentropy (for regular classification)
              metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1024)              1025024
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dense_4 (Dense)             (None, 14)                1806
#
# =================================================================
# Total params: 1,715,854
# Trainable params: 1,715,854
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train,
                    y_train,
                    epochs=50, # you can set this to a big number!
                    batch_size=500,
                    shuffle=True,
                    validation_data=(X_test,y_test),
                    verbose=1)
# Out:
# Epoch 1/50
# 21/21 [==============================] - 5s 77ms/step - loss: 1.8961 - accuracy: 0.3027 - val_loss: 1.2611 - val_accuracy: 0.5040
# Epoch 2/50
# 21/21 [==============================] - 1s 57ms/step - loss: 0.9940 - accuracy: 0.6569 - val_loss: 0.7051 - val_accuracy: 0.7311
# Epoch 3/50
# 21/21 [==============================] - 1s 55ms/step - loss: 0.5509 - accuracy: 0.7912 - val_loss: 0.5673 - val_accuracy: 0.7718
# Epoch 4/50
# 21/21 [==============================] - 1s 55ms/step - loss: 0.3672 - accuracy: 0.8588 - val_loss: 0.2669 - val_accuracy: 0.8865
# Epoch 5/50
# 21/21 [==============================] - 1s 54ms/step - loss: 0.2218 - accuracy: 0.9184 - val_loss: 0.2224 - val_accuracy: 0.9148
# Epoch 6/50
# 21/21 [==============================] - 1s 53ms/step - loss: 0.1685 - accuracy: 0.9420 - val_loss: 0.1849 - val_accuracy: 0.9252
# Epoch 7/50
# 21/21 [==============================] - 1s 55ms/step - loss: 0.1544 - accuracy: 0.9429 - val_loss: 0.1834 - val_accuracy: 0.9249
# Epoch 8/50
# 21/21 [==============================] - 1s 56ms/step - loss: 0.1388 - accuracy: 0.9498 - val_loss: 0.1435 - val_accuracy: 0.9396
# Epoch 9/50
# 21/21 [==============================] - 1s 58ms/step - loss: 0.0768 - accuracy: 0.9802 - val_loss: 0.1106 - val_accuracy: 0.9619
# Epoch 10/50
# 21/21 [==============================] - 1s 69ms/step - loss: 0.0657 - accuracy: 0.9819 - val_loss: 0.1188 - val_accuracy: 0.9639
# Epoch 11/50
# 21/21 [==============================] - 2s 78ms/step - loss: 0.0989 - accuracy: 0.9686 - val_loss: 0.1774 - val_accuracy: 0.9648
# Epoch 12/50
# 21/21 [==============================] - 2s 85ms/step - loss: 0.0565 - accuracy: 0.9886 - val_loss: 0.0645 - val_accuracy: 0.9824
# Epoch 13/50
# 21/21 [==============================] - 2s 83ms/step - loss: 0.0578 - accuracy: 0.9910 - val_loss: 0.1372 - val_accuracy: 0.9674
# Epoch 14/50
# 21/21 [==============================] - 2s 82ms/step - loss: 0.0340 - accuracy: 0.9929 - val_loss: 0.0791 - val_accuracy: 0.9763
# Epoch 15/50
# 21/21 [==============================] - 1s 63ms/step - loss: 0.0243 - accuracy: 0.9953 - val_loss: 0.0538 - val_accuracy: 0.9832
# Epoch 16/50
# 21/21 [==============================] - 1s 58ms/step - loss: 0.1733 - accuracy: 0.9541 - val_loss: 0.1202 - val_accuracy: 0.9688
# Epoch 17/50
# 21/21 [==============================] - 1s 52ms/step - loss: 0.0581 - accuracy: 0.9892 - val_loss: 0.0808 - val_accuracy: 0.9798
# Epoch 18/50
# 21/21 [==============================] - 1s 53ms/step - loss: 0.0224 - accuracy: 0.9966 - val_loss: 0.0621 - val_accuracy: 0.9818
# Epoch 19/50
# 21/21 [==============================] - 1s 55ms/step - loss: 0.0154 - accuracy: 0.9975 - val_loss: 0.0429 - val_accuracy: 0.9882
# Epoch 20/50
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0094 - accuracy: 0.9987 - val_loss: 0.0467 - val_accuracy: 0.9864
# Epoch 21/50
# 21/21 [==============================] - 1s 69ms/step - loss: 0.0075 - accuracy: 0.9993 - val_loss: 0.0434 - val_accuracy: 0.9858
# Epoch 22/50
# 21/21 [==============================] - 1s 68ms/step - loss: 0.0063 - accuracy: 0.9992 - val_loss: 0.0329 - val_accuracy: 0.9899
# Epoch 23/50
# 21/21 [==============================] - 1s 68ms/step - loss: 0.0048 - accuracy: 0.9995 - val_loss: 0.0373 - val_accuracy: 0.9867
# Epoch 24/50
# 21/21 [==============================] - 1s 67ms/step - loss: 0.0044 - accuracy: 0.9995 - val_loss: 0.0516 - val_accuracy: 0.9832
# Epoch 25/50
# 21/21 [==============================] - 1s 66ms/step - loss: 0.0042 - accuracy: 0.9993 - val_loss: 0.0328 - val_accuracy: 0.9884
# Epoch 26/50
# 21/21 [==============================] - 1s 61ms/step - loss: 0.0030 - accuracy: 0.9998 - val_loss: 0.0313 - val_accuracy: 0.9890
# Epoch 27/50
# 21/21 [==============================] - 1s 56ms/step - loss: 0.0024 - accuracy: 0.9999 - val_loss: 0.0339 - val_accuracy: 0.9876
# Epoch 28/50
# 21/21 [==============================] - 1s 50ms/step - loss: 0.0022 - accuracy: 0.9999 - val_loss: 0.0324 - val_accuracy: 0.9890
# Epoch 29/50
# 21/21 [==============================] - 1s 50ms/step - loss: 0.0020 - accuracy: 0.9999 - val_loss: 0.0301 - val_accuracy: 0.9896
# Epoch 30/50
# 21/21 [==============================] - 1s 50ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0314 - val_accuracy: 0.9887
# Epoch 31/50
# 21/21 [==============================] - 1s 55ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9882
# Epoch 32/50
# 21/21 [==============================] - 1s 55ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 0.9882
# Epoch 33/50
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0309 - val_accuracy: 0.9893
# Epoch 34/50
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0307 - val_accuracy: 0.9890
# Epoch 35/50
# 21/21 [==============================] - 1s 66ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0296 - val_accuracy: 0.9890
# Epoch 36/50
# 21/21 [==============================] - 1s 67ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0300 - val_accuracy: 0.9890
# Epoch 37/50
# 21/21 [==============================] - 1s 67ms/step - loss: 7.7425e-04 - accuracy: 1.0000 - val_loss: 0.0295 - val_accuracy: 0.9902
# Epoch 38/50
# 21/21 [==============================] - 1s 67ms/step - loss: 7.3097e-04 - accuracy: 1.0000 - val_loss: 0.0289 - val_accuracy: 0.9890
# Epoch 39/50
# 21/21 [==============================] - 1s 59ms/step - loss: 6.6367e-04 - accuracy: 1.0000 - val_loss: 0.0305 - val_accuracy: 0.9887
# Epoch 40/50
# 21/21 [==============================] - 1s 49ms/step - loss: 5.9775e-04 - accuracy: 1.0000 - val_loss: 0.0303 - val_accuracy: 0.9890
# Epoch 41/50
# 21/21 [==============================] - 1s 52ms/step - loss: 5.6977e-04 - accuracy: 1.0000 - val_loss: 0.0320 - val_accuracy: 0.9887
# Epoch 42/50
# 21/21 [==============================] - 1s 50ms/step - loss: 5.2035e-04 - accuracy: 1.0000 - val_loss: 0.0300 - val_accuracy: 0.9890
# Epoch 43/50
# 21/21 [==============================] - 1s 50ms/step - loss: 4.9670e-04 - accuracy: 1.0000 - val_loss: 0.0299 - val_accuracy: 0.9893
# Epoch 44/50
# 21/21 [==============================] - 1s 51ms/step - loss: 4.8734e-04 - accuracy: 1.0000 - val_loss: 0.0288 - val_accuracy: 0.9896
# Epoch 45/50
# 21/21 [==============================] - 1s 49ms/step - loss: 4.6360e-04 - accuracy: 1.0000 - val_loss: 0.0308 - val_accuracy: 0.9893
# Epoch 46/50
# 21/21 [==============================] - 1s 66ms/step - loss: 4.2603e-04 - accuracy: 1.0000 - val_loss: 0.0289 - val_accuracy: 0.9899
# Epoch 47/50
# 21/21 [==============================] - 1s 66ms/step - loss: 4.0044e-04 - accuracy: 1.0000 - val_loss: 0.0323 - val_accuracy: 0.9884
# Epoch 48/50
# 21/21 [==============================] - 1s 66ms/step - loss: 3.9213e-04 - accuracy: 1.0000 - val_loss: 0.0309 - val_accuracy: 0.9890
# Epoch 49/50
# 21/21 [==============================] - 1s 69ms/step - loss: 3.5802e-04 - accuracy: 1.0000 - val_loss: 0.0289 - val_accuracy: 0.9896
# Epoch 50/50
# 21/21 [==============================] - 1s 67ms/step - loss: 3.3892e-04 - accuracy: 1.0000 - val_loss: 0.0292 - val_accuracy: 0.9896

# %%
plt.plot(history.history['accuracy'],'go--')
plt.plot(history.history['val_accuracy'],'ro--')
plt.legend(['accuray','val_accuracy'])
plt.grid(color='k', linestyle='--', linewidth=0.5)
plt.show()

# %%
def inv_Transform_result(y_pred):    
    y_pred = y_pred.argmax(axis=1)
    y_pred = encoder.inverse_transform(y_pred)
    return y_pred



y_pred=model.predict(X_test)


Y_pred=inv_Transform_result(y_pred)
Y_test = inv_Transform_result(y_test)




from sklearn.metrics import confusion_matrix


plt.figure(figsize=(10,10))
cm = confusion_matrix(Y_test, Y_pred,normalize='true')
f = sns.heatmap(cm, annot=True,xticklabels=encoder.classes_,yticklabels=encoder.classes_)
plt.show()
# Out:
# 109/109 [==============================] - 3s 7ms/step

# %%
dummy_ann = Model(inputs=model.input,outputs=model.layers[-2].output)
y_viz = dummy_ann.predict(X_train)
# Out:
# 325/325 [==============================] - 1s 4ms/step

# %%
y_viz.shape
# Out:
# (10386, 128)

# %%
def T_SNE_plot(X_train,y_train,model,encoder):
    
    dummy_ann = Model(inputs=model.input,outputs=model.layers[-2].output)
    y_viz = dummy_ann.predict(X_train)
    
    from sklearn.manifold import TSNE

    X_t_sne = TSNE(n_components=2, learning_rate='auto',verbose=1, perplexity=40, n_iter=300).fit_transform(y_viz)

    tSNEdf = pd.DataFrame(data = X_t_sne, columns = ['T-SNE component 1', 'T-SNE component 2'])

    tSNEdf['Fault']=inv_Transform_result(y_train)


    # Plot the PC-1 and PC-2
    fig, ax = plt.subplots(figsize=(10,10))
    sns.scatterplot(x=tSNEdf['T-SNE component 1'],y=tSNEdf['T-SNE component 2'],hue='Fault',
        data=tSNEdf,
        legend="full",
        alpha=0.3)
    plt.show()

# %%
T_SNE_plot(X_train,y_train,model,encoder)
# Out:
# 325/325 [==============================] - 1s 4ms/step
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10386 samples in 0.000s...
# [t-SNE] Computed neighbors for 10386 samples in 1.286s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10386
# [t-SNE] Computed conditional probabilities for sample 2000 / 10386
# [t-SNE] Computed conditional probabilities for sample 3000 / 10386
# [t-SNE] Computed conditional probabilities for sample 4000 / 10386
# [t-SNE] Computed conditional probabilities for sample 5000 / 10386
# [t-SNE] Computed conditional probabilities for sample 6000 / 10386
# [t-SNE] Computed conditional probabilities for sample 7000 / 10386
# [t-SNE] Computed conditional probabilities for sample 8000 / 10386
# [t-SNE] Computed conditional probabilities for sample 9000 / 10386
# [t-SNE] Computed conditional probabilities for sample 10000 / 10386
# [t-SNE] Computed conditional probabilities for sample 10386 / 10386
# [t-SNE] Mean sigma: 2.649277
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 63.720982
# [t-SNE] KL divergence after 300 iterations: 2.093738

# %%
def Test_model_diff_loading(load,win_len,stride,model):
    
    df = pd.read_csv('{}hp_all_faults.csv'.format(load))

#     win_len=1000
#     stride=200

    X=[]
    Y=[]


    for k in df['fault'].unique():

        df_temp_2 = df[df['fault']==k]

        for i in np.arange(0,len(df_temp_2)-(win_len),stride):
            temp = df_temp_2.iloc[i:i+win_len,:-1].values
            temp = temp.reshape((1,-1))
            X.append(temp)
            Y.append(df_temp_2.iloc[i+win_len,-1])

    X=np.array(X)
    X=X.reshape((X.shape[0],win_len))



    Y=np.array(Y)
    encoder2= LabelEncoder()
    encoder2.fit(Y)
    encoded_Y = encoder2.transform(Y)
    OHE_Y = to_categorical(encoded_Y)


    def inv_Transform_result(y_pred,encoder):    
        y_pred = y_pred.argmax(axis=1)
        y_pred = encoder.inverse_transform(y_pred)
        return y_pred



    y_pred=model.predict(X)
    
    print('Accuracy on Load-{}hp data is---{}%'.format(load,(model.evaluate(X,OHE_Y)[1])*100))


    Y_pred=inv_Transform_result(y_pred,encoder2)
    Y_test = Y

    from sklearn.metrics import confusion_matrix


    plt.figure(figsize=(10,10))
    cm = confusion_matrix(Y_test, Y_pred,normalize='true')
    f = sns.heatmap(cm, annot=True,xticklabels=encoder.classes_,yticklabels=encoder.classes_)
    plt.show()
    print()
    
    T_SNE_plot(X[::10,:],OHE_Y[::10,:],model,encoder2)

# %%
Test_model_diff_loading(load=1,win_len=1000,stride=200,model=model)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 Test_model_diff_loading(load=1,win_len=1000,stride=200,model=model)
#
# Cell In[16], line 3, in Test_model_diff_loading(load, win_len, stride, model)
#       1 def Test_model_diff_loading(load,win_len,stride,model):
# ----> 3     df = pd.read_csv('{}hp_all_faults.csv'.format(load))
#       5 #     win_len=1000
#       6 #     stride=200
#       8     X=[]
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '1hp_all_faults.csv'

# %%
Test_model_diff_loading(load=2,win_len=1000,stride=200,model=model)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 Test_model_diff_loading(load=2,win_len=1000,stride=200,model=model)
#
# Cell In[16], line 3, in Test_model_diff_loading(load, win_len, stride, model)
#       1 def Test_model_diff_loading(load,win_len,stride,model):
# ----> 3     df = pd.read_csv('{}hp_all_faults.csv'.format(load))
#       5 #     win_len=1000
#       6 #     stride=200
#       8     X=[]
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '2hp_all_faults.csv'

# %%
Test_model_diff_loading(load=3,win_len=1000,stride=200,model=model)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 Test_model_diff_loading(load=3,win_len=1000,stride=200,model=model)
#
# Cell In[16], line 3, in Test_model_diff_loading(load, win_len, stride, model)
#       1 def Test_model_diff_loading(load,win_len,stride,model):
# ----> 3     df = pd.read_csv('{}hp_all_faults.csv'.format(load))
#       5 #     win_len=1000
#       6 #     stride=200
#       8     X=[]
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '3hp_all_faults.csv'
